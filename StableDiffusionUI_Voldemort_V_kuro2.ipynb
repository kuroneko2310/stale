# %% [markdown]
# <a href="https://colab.research.google.com/github/kuroneko2310/stale/blob/main/StableDiffusionUI_Voldemort_V_kuro2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %%
import os
os.kill(os.getpid(), 9) # This will crash Colab (required, everything will still be intact so dont worry)

# %% [markdown]
# # コードクローン

# %% [markdown]
# Clone webui repository

# %%
sumaho=0

# %%
#if sumaho > 0
# print("sumaho");

# %%
# %cd /content
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git
# %cd /content
# Out:
# /content
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 7201, done.
# remote: Total 7201 (delta 0), reused 0 (delta 0), pack-reused 7201
# Receiving objects: 100% (7201/7201), 21.87 MiB | 10.30 MiB/s, done.
# Resolving deltas: 100% (5053/5053), done.
# Cloning into 'a1111-sd-webui-tagcomplete'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 278 (delta 100), reused 143 (delta 69), pack-reused 94
# Receiving objects: 100% (278/278), 1.80 MiB | 2.56 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content

# %%
# %cd /content
shutil.move("/content/a1111-sd-webui-tagcomplete/javascript/tagAutocomplete.js","/content/stable-diffusion-webui/javascript/tagAutocomplete.js")
shutil.move("/content/a1111-sd-webui-tagcomplete/scripts/tag_autocomplete_helper.py","/content/stable-diffusion-webui/scripts/tag_autocomplete_helper.py")
# %cd /content/stable-diffusion-webui
shutil.copytree("/content/a1111-sd-webui-tagcomplete/tags","/content/stable-diffusion-webui/tags")
# Out:
# /content
# /content/stable-diffusion-webui
# '/content/stable-diffusion-webui/tags'

# %%
import os
import shutil
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title インストール
shutil.copytree("/content/drive/MyDrive/AI/git clonestable-diffusion-webui","/content/stable-diffusion-webui")
# Out:
# '/content/stable-diffusion-webui'

# %%
#@title アップロード
shutil.copytree("/content/stable-diffusion-webui","/content/drive/MyDrive/AI/git clonestable-diffusion-webui")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-83e3da47bdd3> in <module>
#       1 #@title コピー
# ----> 2 shutil.copytree("/content/stable-diffusion-webui","/content/drive/MyDrive/AI/git clonestable-diffusion-webui")
#
# /usr/lib/python3.7/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks)
#     316
#     317     """
# --> 318     names = os.listdir(src)
#     319     if ignore is not None:
#     320         ignored_names = ignore(src, names)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/stable-diffusion-webui'

# %%
#shutil.copy("/content/drive/MyDrive/AI/models/sd-v1-4.ckpt", "/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt")

# %% [markdown]
# Download the model from huggingface. See link at the start for different ways.

# %%
#@title Normal 1.4 model
#get a token from https://huggingface.co/settings/tokens
user_token = "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" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/model.ckpt
# Out:
# --2022-10-20 04:20:49--  https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt
# Resolving huggingface.co (huggingface.co)... 52.5.54.249, 52.204.9.116, 44.195.102.200, ...
# Connecting to huggingface.co (huggingface.co)|52.5.54.249|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1666489840&Policy=...&Signature=YH8qqjKc8iwBoRZCPbVF0d8h-5odtojURLyV0X1Edf1DaJ~Q8MKfCaYCKhg7OehWuvAG~NbaJ~lVrJb6-tI~OqZCk~nIvgpfxWsR3M9PflBRzssFGcfIQC7zza19ACMK7EazZIYD45buIf0oEHMngLC5EVdG2z~zqxRJXhDYJBsTML5ab-OJAkp3ZnCBlR6SA3WLXmQ5YxZUx7843mz62kZV7570LJmwyo7FJqnDwVtjFpOD-fuKdgeZnmAD5eZ8Qw1CYEq07rT5Mg20pO09Wc4oHcmDUKW3bUCP9~Ztj8656rSbyU-3RfNcpocToB8MQj6QsTamT3~jm9OMQnuy8g__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2022-10-20 04:20:50--  https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1666489840&Policy=...&Signature=YH8qqjKc8iwBoRZCPbVF0d8h-5odtojURLyV0X1Edf1DaJ~Q8MKfCaYCKhg7OehWuvAG~NbaJ~lVrJb6-tI~OqZCk~nIvgpfxWsR3M9PflBRzssFGcfIQC7zza19ACMK7EazZIYD45buIf0oEHMngLC5EVdG2z~zqxRJXhDYJBsTML5ab-OJAkp3ZnCBlR6SA3WLXmQ5YxZUx7843mz62kZV7570LJmwyo7FJqnDwVtjFpOD-fuKdgeZnmAD5eZ8Qw1CYEq07rT5Mg20pO09Wc4oHcmDUKW3bUCP9~Ztj8656rSbyU-3RfNcpocToB8MQj6QsTamT3~jm9OMQnuy8g__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 13.227.254.52, 13.227.254.33, 13.227.254.47, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|13.227.254.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265380512 (4.0G) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/model.ckpt’
#
# /content/stable-dif 100%[===================>]   3.97G   234MB/s    in 17s
#
# 2022-10-20 04:21:07 (245 MB/s) - ‘/content/stable-diffusion-webui/model.ckpt’ saved [4265380512/4265380512]

# %% [markdown]
# Voldy doesn't explian what this does but it appears to replace the prior dependencies section, saving a few lines lmao

# %% [markdown]
# # モデル コピー

# %%
import os
import shutil
# %cd /content/drive/MyDrive/AI/models
#shutil.copy("/content/drive/MyDrive/AI/models/sd-v1-4.ckpt", "/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt")
#shutil.copy("/content/drive/MyDrive/AI/models/sd-v1-4.ckpt", "/content/stable-diffusion-webui/models/Stable-diffusion/model.ckpt")
#shutil.copy("/content/drive/MyDrive/AI/models/wd-v1-3-full.ckpt", "/contentstable-diffusion-webui/models/Stable-diffusion/wd-v1-3-full.ckpt")
#shutil.copy("/content/drive/MyDrive/AI/models/RD1412.ckpt","/content/stable-diffusion-webui/models/Stable-diffusion/RD1412.ckpt")
#shutil.copy("/content/drive/MyDrive/AI/ckpt/last-pruned.ckpt", "/content/sstable-diffusion-webui/models/Stable-diffusion/last-pruned.ckpt")

# %%
#shutil.copy("/content/drive/MyDrive/AI/ckpt/last-pruned.ckpt", "/content/stable-diffusion-webui/models/Stable-diffusion/last-pruned.ckpt")

# %%
# %cd /content/stable-diffusion-webui/models/Stable-diffusion
# !wget  https://huggingface.co/Deltaadams/Hentai-Diffusion/resolve/1842fc94f1dc3250f6a3d9727e649059414b2560/RD1412.ckpt
# Out:
# /content/stable-diffusion-webui/models/Stable-diffusion
# --2022-10-20 04:21:07--  https://huggingface.co/Deltaadams/Hentai-Diffusion/resolve/1842fc94f1dc3250f6a3d9727e649059414b2560/RD1412.ckpt
# Resolving huggingface.co (huggingface.co)... 52.5.54.249, 54.210.225.113, 52.204.9.116, ...
# Connecting to huggingface.co (huggingface.co)|52.5.54.249|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/fb/07/fb07c776997f32f5659f9fc656b9c195f9a8522e62b12153a3a7af489dc87b26/477b860a6859838e99d81fa5d3345e717e11fe8bd0e7eb32bce7541d57807a4d?response-content-disposition=attachment%3B%20filename%3D%22RD1412.ckpt%22&Expires=1666498868&Policy=..._&Signature=k2UERWcPD5NBSajpjxHZipGmQ~Czm8nmlUqJNpcP15HgJ4ppIFA7~evcnkCRSNISSrnb-WXxh4wTq4FAkubuX-Ih4DEE8ayraLZoSdQUTooEfUe5iBxNLibMxADb0NTqjNeEdwHKJYjLwjpJ5MqLDDN8zX2BJNXCvtQD9xTI~elY--Nnr5GTGd2j1Jz6-8lg7Nm58wVhbBr-F8X5wNofEJV8yuwwYIP6U3a93AAKM3HqxyPeVKQLBm4RdU9nrZpgO5mD0sGOgzDj-lvO73Qy7U1Ef9jhNOBekAt9LU590Xz~AqKql68AOjqXV2qs3oRhUOGrk~XcmLrabq7aVak2sA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2022-10-20 04:21:08--  https://cdn-lfs.huggingface.co/repos/fb/07/fb07c776997f32f5659f9fc656b9c195f9a8522e62b12153a3a7af489dc87b26/477b860a6859838e99d81fa5d3345e717e11fe8bd0e7eb32bce7541d57807a4d?response-content-disposition=attachment%3B%20filename%3D%22RD1412.ckpt%22&Expires=1666498868&Policy=..._&Signature=k2UERWcPD5NBSajpjxHZipGmQ~Czm8nmlUqJNpcP15HgJ4ppIFA7~evcnkCRSNISSrnb-WXxh4wTq4FAkubuX-Ih4DEE8ayraLZoSdQUTooEfUe5iBxNLibMxADb0NTqjNeEdwHKJYjLwjpJ5MqLDDN8zX2BJNXCvtQD9xTI~elY--Nnr5GTGd2j1Jz6-8lg7Nm58wVhbBr-F8X5wNofEJV8yuwwYIP6U3a93AAKM3HqxyPeVKQLBm4RdU9nrZpgO5mD0sGOgzDj-lvO73Qy7U1Ef9jhNOBekAt9LU590Xz~AqKql68AOjqXV2qs3oRhUOGrk~XcmLrabq7aVak2sA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 13.227.254.52, 13.227.254.33, 13.227.254.47, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|13.227.254.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7703712431 (7.2G) [binary/octet-stream]
# Saving to: ‘RD1412.ckpt’
#
# RD1412.ckpt         100%[===================>]   7.17G  17.2MB/s    in 7m 18s
#
# 2022-10-20 04:28:27 (16.8 MB/s) - ‘RD1412.ckpt’ saved [7703712431/7703712431]

# %%
#shutil.copy("/content/drive/MyDrive/AI/models/RD1412.ckpt","/content/stable-diffusion-webui/models/Stable-diffusion/RD1412.ckpt")

# %%
# %cd /content/drive/MyDrive/AI/scripts
shutil.copy("/content/drive/MyDrive/AI/scripts/Stable-diffusion-webui-video-main/videos.py", "/content/stable-diffusion-webui/scripts")
shutil.copy("/content/drive/MyDrive/AI/scripts/StableDiffusionStuff-main/loopback_superimpose.py", "/content/stable-diffusion-webui/scripts")
shutil.copy("/content/drive/MyDrive/AI/scripts/shift-attention-main/scripts/shift_attention.py", "/content/stable-diffusion-webui/scripts")
#shutil.copy("/content/drive/MyDrive/AI/scripts/requirements.txt", "/content/stable-diffusion-webui/")
# Out:
# /content/drive/MyDrive/AI/scripts
# '/content/stable-diffusion-webui/scripts/shift_attention.py'

# %%
# %cd /content/stable-diffusion-webui
shutil.copytree("/content/drive/MyDrive/AI/AgeR-out","/content/stable-diffusion-webui/AgeR-out")

# %% [markdown]
# # メイン web ui 実行

# %%
shutil.copytree("/content/drive/MyDrive/AI/traning AI/AgeRimgis","/content/AR/Ager dis out")
# Out:
# '/content/AR/Ager dis out'

# %%
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--exit " REQS_FILE="requirements.txt" python launch.py
# Out:
# /content/stable-diffusion-webui
# Python 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
# Commit hash: 604620a7f08d1126a8689f9f4bec8ade0801a69b
# Installing gfpgan
# Installing clip
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Exiting because of --exit argument

# %% [markdown]
# Change into Web UI directory and download updates

# %%
# %cd /content/stable-diffusion-webui
# !git pull
# Out:
# /content/stable-diffusion-webui
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 187 (delta 125), reused 129 (delta 125), pack-reused 58
# Receiving objects: 100% (187/187), 66.94 KiB | 22.31 MiB/s, done.
# Resolving deltas: 100% (128/128), completed with 20 local objects.
# From https://github.com/AUTOMATIC1111/stable-diffusion-webui
#    604620a..1ed227b  master             -> origin/master
#    858462f..0c5522e  training-help-text -> origin/training-help-text
# Updating 604620a..1ed227b
# Fast-forward
#  .github/ISSUE_TEMPLATE/config.yml              |   5 +
#  README.md                                      |   1 +
#  modules/extras.py                              |  19 +-
#  modules/hypernetworks/hypernetwork.py          |  46 +++-
#  modules/hypernetworks/ui.py                    |   8 +-
#  modules/interrogate.py                         |  12 +-
#  modules/processing.py                          |  60 ++++-
#  modules/sd_hijack_inpainting.py                | 331 +++++++++++++++++++++++++
#  modules/sd_models.py                           |  21 +-
#  modules/sd_samplers.py                         |  64 ++++-
#  modules/textual_inversion/dataset.py           |   4 +-
#  modules/textual_inversion/preprocess.py        |  40 ++-
#  modules/textual_inversion/textual_inversion.py |   5 +-
#  modules/textual_inversion/ui.py                |   4 +-
#  modules/ui.py                                  |  19 +-
#  scripts/xy_grid.py                             |   1 +
#  webui.py                                       |   5 +-
#  17 files changed, 576 insertions(+), 69 deletions(-)
#  create mode 100644 .github/ISSUE_TEMPLATE/config.yml
#  create mode 100644 modules/sd_hijack_inpainting.py

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty

# %%
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--share  --gradio-debug --deepdanbooru --gradio-auth me:256431" REQS_FILE="requirements.txt" python launch.py
# Out:
# /content/stable-diffusion-webui
# Python 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
# Commit hash: 1ed227b3b57f06f4152be3bfc9f83b0a839a2604
# Installing deepdanbooru
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --deepdanbooru --gradio-auth me:256431
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Downloading: 100% 939k/939k [00:01<00:00, 703kB/s]
# Downloading: 100% 512k/512k [00:01<00:00, 462kB/s]
# Downloading: 100% 389/389 [00:00<00:00, 322kB/s]
# Downloading: 100% 905/905 [00:00<00:00, 737kB/s]
# Downloading: 100% 4.41k/4.41k [00:00<00:00, 2.63MB/s]
# Downloading: 100% 1.59G/1.59G [00:24<00:00, 70.7MB/s]
# Loading weights [7460a6fa] from /content/stable-diffusion-webui/model.ckpt
# Global Step: 470000
# Applying cross attention optimization (Doggettx).
# Model loaded.
# Loaded a total of 1 textual inversion embeddings.
# Embeddings: AgeR
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://4cf08051b909c5b7.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# Loading weights [4fdde306] from /content/stable-diffusion-webui/models/Stable-diffusion/RD1412.ckpt
# Global Step: 619387
# Applying cross attention optimization (Doggettx).
# Weights loaded.
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:03<00:59,  3.11s/it]
#  10% 2/20 [00:03<00:25,  1.42s/it]
#  15% 3/20 [00:03<00:14,  1.13it/s]
#  20% 4/20 [00:03<00:10,  1.59it/s]
#  25% 5/20 [00:04<00:07,  2.04it/s]
#  30% 6/20 [00:04<00:05,  2.46it/s]
#  35% 7/20 [00:04<00:04,  2.84it/s]
#  40% 8/20 [00:04<00:03,  3.15it/s]
#  45% 9/20 [00:05<00:03,  3.40it/s]
#  50% 10/20 [00:05<00:02,  3.59it/s]
#  55% 11/20 [00:05<00:02,  3.74it/s]
#  60% 12/20 [00:05<00:02,  3.85it/s]
#  65% 13/20 [00:06<00:01,  3.92it/s]
#  70% 14/20 [00:06<00:01,  3.98it/s]
#  75% 15/20 [00:06<00:01,  4.02it/s]
#  80% 16/20 [00:06<00:00,  4.07it/s]
#  85% 17/20 [00:06<00:00,  4.10it/s]
#  90% 18/20 [00:07<00:00,  4.10it/s]
#  95% 19/20 [00:07<00:00,  4.09it/s]
# 100% 20/20 [00:07<00:00,  2.59it/s]
# Total progress: 20it [00:04,  4.05it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.26it/s]
#  10% 2/20 [00:00<00:04,  3.73it/s]
#  15% 3/20 [00:00<00:04,  3.88it/s]
#  20% 4/20 [00:01<00:04,  3.97it/s]
#  25% 5/20 [00:01<00:03,  3.97it/s]
#  30% 6/20 [00:01<00:03,  4.01it/s]
#  35% 7/20 [00:01<00:03,  4.04it/s]
#  40% 8/20 [00:02<00:02,  4.07it/s]
#  45% 9/20 [00:02<00:02,  4.05it/s]
#  50% 10/20 [00:02<00:02,  4.06it/s]
#  55% 11/20 [00:02<00:02,  4.07it/s]
#  60% 12/20 [00:03<00:01,  4.05it/s]
#  65% 13/20 [00:03<00:01,  4.04it/s]
#  70% 14/20 [00:03<00:01,  4.05it/s]
#  75% 15/20 [00:03<00:01,  4.06it/s]
#  80% 16/20 [00:03<00:00,  4.06it/s]
#  85% 17/20 [00:04<00:00,  4.06it/s]
#  90% 18/20 [00:04<00:00,  4.04it/s]
#  95% 19/20 [00:04<00:00,  4.05it/s]
# 100% 20/20 [00:04<00:00,  4.02it/s]
# Total progress: 100% 20/20 [00:05<00:00,  3.98it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:06,  3.02it/s]
#  10% 2/20 [00:00<00:05,  3.48it/s]
#  15% 3/20 [00:00<00:04,  3.65it/s]
#  20% 4/20 [00:01<00:04,  3.74it/s]
#  25% 5/20 [00:01<00:04,  3.74it/s]
#  30% 6/20 [00:01<00:03,  3.78it/s]
#  35% 7/20 [00:01<00:03,  3.80it/s]
#  40% 8/20 [00:02<00:03,  3.82it/s]
#  45% 9/20 [00:02<00:02,  3.82it/s]
#  50% 10/20 [00:02<00:02,  3.82it/s]
#  55% 11/20 [00:02<00:02,  3.82it/s]
#  60% 12/20 [00:03<00:02,  3.82it/s]
#  65% 13/20 [00:03<00:01,  3.82it/s]
#  70% 14/20 [00:03<00:01,  3.81it/s]
#  75% 15/20 [00:03<00:01,  3.81it/s]
#  80% 16/20 [00:04<00:01,  3.83it/s]
#  85% 17/20 [00:04<00:00,  3.83it/s]
#  90% 18/20 [00:04<00:00,  3.83it/s]
#  95% 19/20 [00:05<00:00,  3.82it/s]
# 100% 20/20 [00:05<00:00,  3.78it/s]
# Total progress: 100% 20/20 [00:05<00:00,  3.77it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.19it/s]
#  10% 2/20 [00:00<00:05,  3.59it/s]
#  15% 3/20 [00:00<00:04,  3.72it/s]
#  20% 4/20 [00:01<00:04,  3.77it/s]
#  25% 5/20 [00:01<00:03,  3.77it/s]
#  30% 6/20 [00:01<00:03,  3.81it/s]
#  35% 7/20 [00:01<00:03,  3.83it/s]
#  40% 8/20 [00:02<00:03,  3.81it/s]
#  45% 9/20 [00:02<00:02,  3.80it/s]
#  50% 10/20 [00:02<00:02,  3.82it/s]
#  55% 11/20 [00:02<00:02,  3.83it/s]
#  60% 12/20 [00:03<00:02,  3.81it/s]
#  65% 13/20 [00:03<00:01,  3.81it/s]
#  70% 14/20 [00:03<00:01,  3.82it/s]
#  75% 15/20 [00:03<00:01,  3.83it/s]
#  80% 16/20 [00:04<00:01,  3.82it/s]
#  85% 17/20 [00:04<00:00,  3.82it/s]
#  90% 18/20 [00:04<00:00,  3.81it/s]
#  95% 19/20 [00:05<00:00,  3.81it/s]
# 100% 20/20 [00:05<00:00,  3.79it/s]
# Total progress: 100% 20/20 [00:05<00:00,  3.78it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.56it/s]
#  10% 2/20 [00:00<00:04,  4.12it/s]
#  15% 3/20 [00:00<00:03,  4.33it/s]
#  20% 4/20 [00:00<00:03,  4.45it/s]
#  25% 5/20 [00:01<00:03,  4.35it/s]
#  30% 6/20 [00:01<00:03,  4.37it/s]
#  35% 7/20 [00:01<00:02,  4.41it/s]
#  40% 8/20 [00:01<00:02,  4.46it/s]
#  45% 9/20 [00:02<00:02,  4.49it/s]
#  50% 10/20 [00:02<00:02,  4.42it/s]
#  55% 11/20 [00:02<00:02,  4.45it/s]
#  60% 12/20 [00:02<00:01,  4.49it/s]
#  65% 13/20 [00:02<00:01,  4.53it/s]
#  70% 14/20 [00:03<00:01,  4.47it/s]
#  75% 15/20 [00:03<00:01,  4.44it/s]
#  80% 16/20 [00:03<00:00,  4.48it/s]
#  85% 17/20 [00:03<00:00,  4.51it/s]
#  90% 18/20 [00:04<00:00,  4.52it/s]
#  95% 19/20 [00:04<00:00,  4.44it/s]
# 100% 20/20 [00:04<00:00,  4.43it/s]
# Total progress: 100% 20/20 [00:04<00:00,  4.39it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.45it/s]
#  10% 2/20 [00:00<00:04,  4.08it/s]
#  15% 3/20 [00:00<00:03,  4.33it/s]
#  20% 4/20 [00:00<00:03,  4.42it/s]
#  25% 5/20 [00:01<00:03,  4.38it/s]
#  30% 6/20 [00:01<00:03,  4.35it/s]
#  35% 7/20 [00:01<00:02,  4.42it/s]
#  40% 8/20 [00:01<00:02,  4.49it/s]
#  45% 9/20 [00:02<00:02,  4.50it/s]
#  50% 10/20 [00:02<00:02,  4.40it/s]
#  55% 11/20 [00:02<00:02,  4.43it/s]
#  60% 12/20 [00:02<00:01,  4.47it/s]
#  65% 13/20 [00:02<00:01,  4.53it/s]
#  70% 14/20 [00:03<00:01,  4.47it/s]
#  75% 15/20 [00:03<00:01,  4.42it/s]
#  80% 16/20 [00:03<00:00,  4.46it/s]
#  85% 17/20 [00:03<00:00,  4.51it/s]
#  90% 18/20 [00:04<00:00,  4.52it/s]
#  95% 19/20 [00:04<00:00,  4.43it/s]
# 100% 20/20 [00:04<00:00,  4.42it/s]
# Total progress: 100% 20/20 [00:04<00:00,  4.36it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.60it/s]
#  10% 2/20 [00:00<00:04,  4.13it/s]
#  15% 3/20 [00:00<00:03,  4.38it/s]
#  20% 4/20 [00:00<00:03,  4.48it/s]
#  25% 5/20 [00:01<00:03,  4.46it/s]
#  30% 6/20 [00:01<00:03,  4.45it/s]
#  35% 7/20 [00:01<00:02,  4.47it/s]
#  40% 8/20 [00:01<00:02,  4.52it/s]
#  45% 9/20 [00:02<00:02,  4.56it/s]
#  50% 10/20 [00:02<00:02,  4.52it/s]
#  55% 11/20 [00:02<00:01,  4.51it/s]
#  60% 12/20 [00:02<00:01,  4.52it/s]
#  65% 13/20 [00:02<00:01,  4.54it/s]
#  70% 14/20 [00:03<00:01,  4.51it/s]
#  75% 15/20 [00:03<00:01,  4.50it/s]
#  80% 16/20 [00:03<00:00,  4.50it/s]
#  85% 17/20 [00:03<00:00,  4.50it/s]
#  90% 18/20 [00:04<00:00,  4.51it/s]
#  95% 19/20 [00:04<00:00,  4.49it/s]
# 100% 20/20 [00:04<00:00,  4.47it/s]
# Total progress: 100% 20/20 [00:04<00:00,  4.45it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:20,  1.08s/it]
#  10% 2/20 [00:02<00:19,  1.07s/it]
#  15% 3/20 [00:03<00:18,  1.07s/it]
#  20% 4/20 [00:04<00:17,  1.07s/it]
#  25% 5/20 [00:05<00:16,  1.08s/it]
#  30% 6/20 [00:06<00:15,  1.08s/it]
#  35% 7/20 [00:07<00:14,  1.09s/it]
#  40% 8/20 [00:08<00:13,  1.09s/it]
#  45% 9/20 [00:09<00:12,  1.09s/it]
#  50% 10/20 [00:10<00:10,  1.10s/it]
#  55% 11/20 [00:11<00:09,  1.10s/it]
#  60% 12/20 [00:13<00:08,  1.11s/it]
#  65% 13/20 [00:14<00:07,  1.11s/it]
#  70% 14/20 [00:15<00:06,  1.12s/it]
#  75% 15/20 [00:16<00:05,  1.12s/it]
#  80% 16/20 [00:17<00:04,  1.12s/it]
#  85% 17/20 [00:18<00:03,  1.12s/it]
#  90% 18/20 [00:19<00:02,  1.12s/it]
#  95% 19/20 [00:20<00:01,  1.12s/it]
# 100% 20/20 [00:22<00:00,  1.10s/it]
# Total progress: 20it [00:27,  1.37s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:19,  1.01s/it]
#  10% 2/20 [00:02<00:17,  1.00it/s]
#  15% 3/20 [00:02<00:16,  1.00it/s]
#  20% 4/20 [00:03<00:15,  1.00it/s]
#  25% 5/20 [00:05<00:15,  1.00s/it]
#  30% 6/20 [00:06<00:14,  1.00s/it]
#  35% 7/20 [00:07<00:13,  1.01s/it]
#  40% 8/20 [00:08<00:12,  1.01s/it]
#  45% 9/20 [00:09<00:11,  1.01s/it]
#  50% 10/20 [00:10<00:10,  1.02s/it]
#  55% 11/20 [00:11<00:09,  1.02s/it]
#  60% 12/20 [00:12<00:08,  1.02s/it]
#  65% 13/20 [00:13<00:07,  1.03s/it]
#  70% 14/20 [00:14<00:06,  1.03s/it]
#  75% 15/20 [00:15<00:05,  1.04s/it]
#  80% 16/20 [00:16<00:04,  1.04s/it]
#  85% 17/20 [00:17<00:03,  1.05s/it]
#  90% 18/20 [00:18<00:02,  1.06s/it]
#  95% 19/20 [00:19<00:01,  1.06s/it]
# 100% 20/20 [00:20<00:00,  1.03s/it]
# Total progress: 100% 20/20 [00:21<00:00,  1.10s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:19,  1.04s/it]
#  10% 2/20 [00:02<00:18,  1.03s/it]
#  15% 3/20 [00:03<00:17,  1.03s/it]
#  20% 4/20 [00:04<00:16,  1.04s/it]
#  25% 5/20 [00:05<00:15,  1.04s/it]
#  30% 6/20 [00:06<00:14,  1.05s/it]
#  35% 7/20 [00:07<00:13,  1.05s/it]
#  40% 8/20 [00:08<00:12,  1.06s/it]
#  45% 9/20 [00:09<00:11,  1.06s/it]
#  50% 10/20 [00:10<00:10,  1.07s/it]
#  55% 11/20 [00:11<00:09,  1.07s/it]
#  60% 12/20 [00:12<00:08,  1.08s/it]
#  65% 13/20 [00:13<00:07,  1.08s/it]
#  70% 14/20 [00:14<00:06,  1.09s/it]
#  75% 15/20 [00:16<00:05,  1.09s/it]
#  80% 16/20 [00:17<00:04,  1.10s/it]
#  85% 17/20 [00:18<00:03,  1.10s/it]
#  90% 18/20 [00:19<00:02,  1.11s/it]
#  95% 19/20 [00:20<00:01,  1.11s/it]
# 100% 20/20 [00:21<00:00,  1.08s/it]
# Total progress: 100% 20/20 [00:22<00:00,  1.14s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:19,  1.01s/it]
#  10% 2/20 [00:02<00:18,  1.00s/it]
#  15% 3/20 [00:03<00:17,  1.00s/it]
#  20% 4/20 [00:04<00:16,  1.01s/it]
#  25% 5/20 [00:05<00:15,  1.02s/it]
#  30% 6/20 [00:06<00:14,  1.02s/it]
#  35% 7/20 [00:07<00:13,  1.02s/it]
#  40% 8/20 [00:08<00:12,  1.02s/it]
#  45% 9/20 [00:09<00:11,  1.03s/it]
#  50% 10/20 [00:10<00:10,  1.03s/it]
#  55% 11/20 [00:11<00:09,  1.04s/it]
#  60% 12/20 [00:12<00:08,  1.04s/it]
#  65% 13/20 [00:13<00:07,  1.05s/it]
#  70% 14/20 [00:14<00:06,  1.06s/it]
#  75% 15/20 [00:15<00:05,  1.06s/it]
#  80% 16/20 [00:16<00:04,  1.07s/it]
#  85% 17/20 [00:17<00:03,  1.07s/it]
#  90% 18/20 [00:18<00:02,  1.07s/it]
#  95% 19/20 [00:19<00:01,  1.08s/it]
# 100% 20/20 [00:20<00:00,  1.05s/it]
# Total progress: 100% 20/20 [00:22<00:00,  1.11s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:19,  1.02s/it]
#  10% 2/20 [00:02<00:18,  1.03s/it]
#  15% 3/20 [00:03<00:17,  1.04s/it]
#  20% 4/20 [00:04<00:16,  1.04s/it]
#  25% 5/20 [00:05<00:15,  1.05s/it]
#  30% 6/20 [00:06<00:14,  1.05s/it]
#  35% 7/20 [00:07<00:13,  1.06s/it]
#  40% 8/20 [00:08<00:12,  1.06s/it]
#  45% 9/20 [00:09<00:11,  1.07s/it]
#  50% 10/20 [00:10<00:10,  1.07s/it]
#  55% 11/20 [00:11<00:09,  1.08s/it]
#  60% 12/20 [00:12<00:08,  1.08s/it]
#  65% 13/20 [00:13<00:07,  1.09s/it]
#  70% 14/20 [00:14<00:06,  1.09s/it]
#  75% 15/20 [00:16<00:05,  1.10s/it]
#  80% 16/20 [00:17<00:04,  1.10s/it]
#  85% 17/20 [00:18<00:03,  1.11s/it]
#  90% 18/20 [00:19<00:02,  1.11s/it]
#  95% 19/20 [00:20<00:01,  1.11s/it]
# 100% 20/20 [00:21<00:00,  1.08s/it]
# Total progress: 100% 20/20 [00:24<00:00,  1.22s/it]
# Preparing dataset...
# 100% 694/694 [01:21<00:00,  8.54it/s]
# Training at rate of 1e-05 until step 3000
# loss: 0.1763646:   2% 50/3000 [00:37<36:17,  1.35it/s]
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 0/60000 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.32it/s]
# Total progress:   0% 2/60000 [00:00<2:31:10,  6.61it/s]
#  10% 2/20 [00:00<00:05,  3.31it/s]
# Total progress:   0% 3/60000 [00:00<3:43:52,  4.47it/s]
#  15% 3/20 [00:00<00:05,  3.20it/s]
# Total progress:   0% 4/60000 [00:00<4:14:13,  3.93it/s]
#  20% 4/20 [00:01<00:04,  3.23it/s]
# Total progress:   0% 5/60000 [00:01<4:30:52,  3.69it/s]
#  25% 5/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 6/60000 [00:01<4:42:06,  3.54it/s]
#  30% 6/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 7/60000 [00:01<4:53:25,  3.41it/s]
#  35% 7/20 [00:02<00:04,  3.23it/s]
# Total progress:   0% 8/60000 [00:02<4:55:58,  3.38it/s]
#  40% 8/20 [00:02<00:03,  3.25it/s]
# Total progress:   0% 9/60000 [00:02<4:58:59,  3.34it/s]
#  45% 9/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 10/60000 [00:02<5:02:59,  3.30it/s]
#  50% 10/20 [00:03<00:03,  3.24it/s]
# Total progress:   0% 11/60000 [00:03<5:03:58,  3.29it/s]
#  55% 11/20 [00:03<00:02,  3.25it/s]
# Total progress:   0% 12/60000 [00:03<5:03:32,  3.29it/s]
#  60% 12/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 13/60000 [00:03<5:04:55,  3.28it/s]
#  65% 13/20 [00:03<00:02,  3.26it/s]
# Total progress:   0% 14/60000 [00:04<5:06:08,  3.27it/s]
#  70% 14/20 [00:04<00:01,  3.25it/s]
# Total progress:   0% 15/60000 [00:04<5:05:05,  3.28it/s]
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 16/60000 [00:04<5:05:55,  3.27it/s]
#  80% 16/20 [00:04<00:01,  3.26it/s]
# Total progress:   0% 17/60000 [00:04<5:06:11,  3.26it/s]
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 18/60000 [00:05<5:05:36,  3.27it/s]
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 19/60000 [00:05<5:05:33,  3.27it/s]
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 20/60000 [00:05<5:05:50,  3.27it/s]
# 100% 20/20 [00:06<00:00,  3.26it/s]
# loss: 0.1557412:   3% 100/3000 [01:21<34:20,  1.41it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 21/60000 [00:43<193:56:47, 11.64s/it]
#
#   5% 1/20 [00:00<00:05,  3.37it/s]
# Total progress:   0% 22/60000 [00:44<137:14:28,  8.24s/it]
#
#  10% 2/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 23/60000 [00:44<97:38:28,  5.86s/it]
#
#  15% 3/20 [00:00<00:05,  3.26it/s]
# Total progress:   0% 24/60000 [00:44<69:52:13,  4.19s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 25/60000 [00:45<50:23:51,  3.03s/it]
#
#  25% 5/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 26/60000 [00:45<36:47:08,  2.21s/it]
#
#  30% 6/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 27/60000 [00:45<27:18:25,  1.64s/it]
#
#  35% 7/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 28/60000 [00:46<20:36:30,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 29/60000 [00:46<15:55:57,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   0% 30/60000 [00:46<12:43:47,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   0% 31/60000 [00:46<10:25:17,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 32/60000 [00:47<8:48:03,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 33/60000 [00:47<7:41:22,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 34/60000 [00:47<6:54:29,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 35/60000 [00:48<6:20:44,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 36/60000 [00:48<5:57:16,  2.80it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 37/60000 [00:48<5:42:02,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 38/60000 [00:49<5:29:49,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 39/60000 [00:49<5:21:36,  3.11it/s]
#
#  95% 19/20 [00:05<00:00,  3.30it/s]
# Total progress:   0% 40/60000 [00:49<5:17:11,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.29it/s]
# loss: 0.1414970:   5% 150/3000 [02:04<32:37,  1.46it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 41/60000 [01:26<189:16:25, 11.36s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 42/60000 [01:27<133:59:14,  8.04s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 43/60000 [01:27<95:23:28,  5.73s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   0% 44/60000 [01:27<68:17:42,  4.10s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 45/60000 [01:28<49:18:41,  2.96s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 46/60000 [01:28<36:02:55,  2.16s/it]
#
#  30% 6/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 47/60000 [01:28<26:47:48,  1.61s/it]
#
#  35% 7/20 [00:02<00:04,  3.25it/s]
# Total progress:   0% 48/60000 [01:28<20:15:27,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 49/60000 [01:29<15:40:54,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 50/60000 [01:29<12:31:57,  1.33it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 51/60000 [01:29<10:17:18,  1.62it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 52/60000 [01:30<8:42:36,  1.91it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 53/60000 [01:30<7:38:01,  2.18it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 54/60000 [01:30<6:52:50,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 55/60000 [01:31<6:19:54,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 56/60000 [01:31<5:57:15,  2.80it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 57/60000 [01:31<5:42:38,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 58/60000 [01:32<5:30:47,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 59/60000 [01:32<5:22:40,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 60/60000 [01:32<5:17:38,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1416497:   7% 200/3000 [02:47<34:12,  1.36it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 61/60000 [02:09<189:03:36, 11.36s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   0% 62/60000 [02:10<133:50:23,  8.04s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 63/60000 [02:10<95:15:08,  5.72s/it]
#
#  15% 3/20 [00:00<00:05,  3.27it/s]
# Total progress:   0% 64/60000 [02:10<68:12:41,  4.10s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 65/60000 [02:10<49:14:04,  2.96s/it]
#
#  25% 5/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 66/60000 [02:11<35:58:19,  2.16s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 67/60000 [02:11<26:43:32,  1.61s/it]
#
#  35% 7/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 68/60000 [02:11<20:12:50,  1.21s/it]
#
#  40% 8/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 69/60000 [02:12<15:39:00,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   0% 70/60000 [02:12<12:30:17,  1.33it/s]
#
#  50% 10/20 [00:03<00:03,  3.28it/s]
# Total progress:   0% 71/60000 [02:12<10:16:18,  1.62it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 72/60000 [02:13<8:41:36,  1.91it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 73/60000 [02:13<7:36:42,  2.19it/s]
#
#  65% 13/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 74/60000 [02:13<6:51:14,  2.43it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 75/60000 [02:14<6:18:07,  2.64it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 76/60000 [02:14<5:54:59,  2.81it/s]
#
#  80% 16/20 [00:04<00:01,  3.30it/s]
# Total progress:   0% 77/60000 [02:14<5:40:02,  2.94it/s]
#
#  85% 17/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 78/60000 [02:14<5:29:13,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 79/60000 [02:15<5:20:52,  3.11it/s]
#
#  95% 19/20 [00:05<00:00,  3.30it/s]
# Total progress:   0% 80/60000 [02:15<5:16:10,  3.16it/s]
#
# 100% 20/20 [00:06<00:00,  3.29it/s]
# loss: 0.1562943:   8% 250/3000 [03:31<32:57,  1.39it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 81/60000 [02:53<192:52:17, 11.59s/it]
#
#   5% 1/20 [00:00<00:05,  3.29it/s]
# Total progress:   0% 82/60000 [02:53<136:30:59,  8.20s/it]
#
#  10% 2/20 [00:00<00:05,  3.30it/s]
# Total progress:   0% 83/60000 [02:54<97:09:56,  5.84s/it]
#
#  15% 3/20 [00:00<00:05,  3.21it/s]
# Total progress:   0% 84/60000 [02:54<69:32:05,  4.18s/it]
#
#  20% 4/20 [00:01<00:04,  3.24it/s]
# Total progress:   0% 85/60000 [02:54<50:10:20,  3.01s/it]
#
#  25% 5/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 86/60000 [02:54<36:37:42,  2.20s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 87/60000 [02:55<27:12:31,  1.63s/it]
#
#  35% 7/20 [00:02<00:03,  3.25it/s]
# Total progress:   0% 88/60000 [02:55<20:33:22,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 89/60000 [02:55<15:54:08,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 90/60000 [02:56<12:40:58,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   0% 91/60000 [02:56<10:23:55,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 92/60000 [02:56<8:46:53,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 93/60000 [02:57<7:40:59,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 94/60000 [02:57<6:54:30,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 95/60000 [02:57<6:21:41,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 96/60000 [02:58<5:59:26,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.26it/s]
# Total progress:   0% 97/60000 [02:58<5:44:31,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.25it/s]
# Total progress:   0% 98/60000 [02:58<5:32:05,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 99/60000 [02:58<5:23:33,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 100/60000 [02:59<5:18:14,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1448821:  10% 300/3000 [04:14<34:07,  1.32it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 101/60000 [03:37<193:32:12, 11.63s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 102/60000 [03:37<136:58:10,  8.23s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 103/60000 [03:37<97:26:35,  5.86s/it]
#
#  15% 3/20 [00:00<00:05,  3.27it/s]
# Total progress:   0% 104/60000 [03:38<69:44:29,  4.19s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 105/60000 [03:38<50:18:31,  3.02s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 106/60000 [03:38<36:42:58,  2.21s/it]
#
#  30% 6/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 107/60000 [03:39<27:14:41,  1.64s/it]
#
#  35% 7/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 108/60000 [03:39<20:34:39,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 109/60000 [03:39<15:54:27,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   0% 110/60000 [03:40<12:41:24,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 111/60000 [03:40<10:23:44,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 112/60000 [03:40<8:47:10,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 113/60000 [03:40<7:41:02,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 114/60000 [03:41<6:54:50,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 115/60000 [03:41<6:21:02,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 116/60000 [03:41<5:59:07,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 117/60000 [03:42<5:43:35,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 118/60000 [03:42<5:31:07,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 119/60000 [03:42<5:23:29,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 120/60000 [03:43<5:17:45,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1668494:  12% 350/3000 [05:00<37:38,  1.17it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 121/60000 [04:22<202:28:56, 12.17s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   0% 122/60000 [04:23<143:13:56,  8.61s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 123/60000 [04:23<101:50:42,  6.12s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   0% 124/60000 [04:23<72:48:28,  4.38s/it]
#
#  20% 4/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 125/60000 [04:24<52:28:35,  3.16s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 126/60000 [04:24<38:14:54,  2.30s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 127/60000 [04:24<28:19:48,  1.70s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 128/60000 [04:25<21:20:01,  1.28s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 129/60000 [04:25<16:26:56,  1.01it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 130/60000 [04:25<13:04:20,  1.27it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   0% 131/60000 [04:25<10:39:31,  1.56it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 132/60000 [04:26<8:57:47,  1.86it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 133/60000 [04:26<7:48:41,  2.13it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 134/60000 [04:26<6:59:34,  2.38it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 135/60000 [04:27<6:24:11,  2.60it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 136/60000 [04:27<5:59:39,  2.77it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 137/60000 [04:27<5:43:29,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 138/60000 [04:28<5:31:32,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 139/60000 [04:28<5:22:48,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 140/60000 [04:28<5:17:30,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1350097:  13% 400/3000 [05:43<33:28,  1.29it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 141/60000 [05:06<191:50:24, 11.54s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 142/60000 [05:06<135:46:56,  8.17s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 143/60000 [05:07<96:36:36,  5.81s/it]
#
#  15% 3/20 [00:00<00:05,  3.27it/s]
# Total progress:   0% 144/60000 [05:07<69:09:32,  4.16s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 145/60000 [05:07<49:54:07,  3.00s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 146/60000 [05:07<36:26:03,  2.19s/it]
#
#  30% 6/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 147/60000 [05:08<27:03:32,  1.63s/it]
#
#  35% 7/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 148/60000 [05:08<20:26:43,  1.23s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 149/60000 [05:08<15:48:41,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   0% 150/60000 [05:09<12:36:51,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 151/60000 [05:09<10:20:31,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 152/60000 [05:09<8:44:28,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 153/60000 [05:10<7:39:13,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 154/60000 [05:10<6:53:42,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 155/60000 [05:10<6:20:25,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 156/60000 [05:10<5:56:50,  2.80it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 157/60000 [05:11<5:41:25,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 158/60000 [05:11<5:30:42,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 159/60000 [05:11<5:21:47,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 160/60000 [05:12<5:16:36,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1414417:  15% 450/3000 [06:27<30:12,  1.41it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 161/60000 [05:49<190:29:09, 11.46s/it]
#
#   5% 1/20 [00:00<00:05,  3.33it/s]
# Total progress:   0% 162/60000 [05:49<134:50:08,  8.11s/it]
#
#  10% 2/20 [00:00<00:05,  3.33it/s]
# Total progress:   0% 163/60000 [05:50<95:58:07,  5.77s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   0% 164/60000 [05:50<68:41:39,  4.13s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 165/60000 [05:50<49:35:01,  2.98s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 166/60000 [05:51<36:13:31,  2.18s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 167/60000 [05:51<26:54:26,  1.62s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 168/60000 [05:51<20:20:27,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 169/60000 [05:52<15:44:24,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 170/60000 [05:52<12:33:31,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 171/60000 [05:52<10:19:25,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 172/60000 [05:53<8:43:58,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 173/60000 [05:53<7:38:56,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 174/60000 [05:53<6:52:03,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 175/60000 [05:53<6:19:43,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 176/60000 [05:54<5:58:01,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 177/60000 [05:54<5:42:20,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 178/60000 [05:54<5:31:10,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 179/60000 [05:55<5:23:13,  3.08it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 180/60000 [05:55<5:17:10,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1622263:  17% 500/3000 [07:10<28:55,  1.44it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 181/60000 [06:32<190:30:41, 11.47s/it]
#
#   5% 1/20 [00:00<00:05,  3.33it/s]
# Total progress:   0% 182/60000 [06:33<134:50:29,  8.12s/it]
#
#  10% 2/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 183/60000 [06:33<95:58:10,  5.78s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   0% 184/60000 [06:33<68:42:26,  4.14s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 185/60000 [06:34<49:35:30,  2.98s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 186/60000 [06:34<36:14:06,  2.18s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 187/60000 [06:34<26:54:30,  1.62s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 188/60000 [06:35<20:20:41,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 189/60000 [06:35<15:44:50,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 190/60000 [06:35<12:33:42,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 191/60000 [06:36<10:19:26,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 192/60000 [06:36<8:44:19,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 193/60000 [06:36<7:39:25,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.26it/s]
# Total progress:   0% 194/60000 [06:36<6:52:52,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 195/60000 [06:37<6:20:15,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 196/60000 [06:37<5:58:00,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 197/60000 [06:37<5:42:11,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 198/60000 [06:38<5:30:54,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 199/60000 [06:38<5:22:31,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 200/60000 [06:38<5:17:24,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1656931:  18% 550/3000 [07:54<30:21,  1.35it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 201/60000 [07:16<192:34:07, 11.59s/it]
#
#   5% 1/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 202/60000 [07:16<136:18:00,  8.21s/it]
#
#  10% 2/20 [00:00<00:05,  3.33it/s]
# Total progress:   0% 203/60000 [07:17<96:59:32,  5.84s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   0% 204/60000 [07:17<69:26:05,  4.18s/it]
#
#  20% 4/20 [00:01<00:04,  3.24it/s]
# Total progress:   0% 205/60000 [07:17<50:06:27,  3.02s/it]
#
#  25% 5/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 206/60000 [07:18<36:35:50,  2.20s/it]
#
#  30% 6/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 207/60000 [07:18<27:11:30,  1.64s/it]
#
#  35% 7/20 [00:02<00:04,  3.23it/s]
# Total progress:   0% 208/60000 [07:18<20:31:47,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 209/60000 [07:19<15:52:50,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 210/60000 [07:19<12:40:30,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.25it/s]
# Total progress:   0% 211/60000 [07:19<10:23:07,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.26it/s]
# Total progress:   0% 212/60000 [07:20<8:46:34,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 213/60000 [07:20<7:40:39,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 214/60000 [07:20<6:53:45,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 215/60000 [07:20<6:19:37,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 216/60000 [07:21<5:56:53,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 217/60000 [07:21<5:41:17,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 218/60000 [07:21<5:29:13,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 219/60000 [07:22<5:20:36,  3.11it/s]
#
#  95% 19/20 [00:05<00:00,  3.30it/s]
# Total progress:   0% 220/60000 [07:22<5:16:35,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1558053:  20% 600/3000 [08:38<29:51,  1.34it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 221/60000 [08:00<193:04:20, 11.63s/it]
#
#   5% 1/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 222/60000 [08:00<136:38:23,  8.23s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 223/60000 [08:01<97:13:43,  5.86s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   0% 224/60000 [08:01<69:34:50,  4.19s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   0% 225/60000 [08:01<50:12:25,  3.02s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 226/60000 [08:02<36:39:25,  2.21s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   0% 227/60000 [08:02<27:13:44,  1.64s/it]
#
#  35% 7/20 [00:02<00:04,  3.25it/s]
# Total progress:   0% 228/60000 [08:02<20:34:05,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 229/60000 [08:02<15:54:17,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 230/60000 [08:03<12:41:10,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   0% 231/60000 [08:03<10:23:23,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 232/60000 [08:03<8:46:15,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 233/60000 [08:04<7:40:49,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 234/60000 [08:04<6:54:07,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 235/60000 [08:04<6:19:42,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 236/60000 [08:05<5:58:16,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 237/60000 [08:05<5:42:47,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 238/60000 [08:05<5:31:58,  3.00it/s]
#
#  90% 18/20 [00:05<00:00,  3.26it/s]
# Total progress:   0% 239/60000 [08:06<5:23:14,  3.08it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 240/60000 [08:06<5:16:53,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1553632:  22% 650/3000 [09:22<27:52,  1.41it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 241/60000 [08:44<194:13:51, 11.70s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   0% 242/60000 [08:44<137:27:16,  8.28s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   0% 243/60000 [08:45<97:48:34,  5.89s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   0% 244/60000 [08:45<69:59:25,  4.22s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   0% 245/60000 [08:45<50:29:57,  3.04s/it]
#
#  25% 5/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 246/60000 [08:46<36:50:57,  2.22s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 247/60000 [08:46<27:20:54,  1.65s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   0% 248/60000 [08:46<20:38:58,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 249/60000 [08:47<15:57:33,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 250/60000 [08:47<12:42:33,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   0% 251/60000 [08:47<10:26:09,  1.59it/s]
#
#  55% 11/20 [00:03<00:02,  3.26it/s]
# Total progress:   0% 252/60000 [08:47<8:48:52,  1.88it/s]
#
#  60% 12/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 253/60000 [08:48<7:42:20,  2.15it/s]
#
#  65% 13/20 [00:03<00:02,  3.26it/s]
# Total progress:   0% 254/60000 [08:48<6:55:45,  2.40it/s]
#
#  70% 14/20 [00:04<00:01,  3.26it/s]
# Total progress:   0% 255/60000 [08:48<6:21:31,  2.61it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 256/60000 [08:49<5:58:18,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 257/60000 [08:49<5:42:38,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   0% 258/60000 [08:49<5:30:24,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 259/60000 [08:50<5:21:15,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 260/60000 [08:50<5:15:55,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1554270:  23% 700/3000 [10:06<28:24,  1.35it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 261/60000 [09:29<196:19:50, 11.83s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   0% 262/60000 [09:29<138:55:49,  8.37s/it]
#
#  10% 2/20 [00:00<00:05,  3.33it/s]
# Total progress:   0% 263/60000 [09:29<98:49:48,  5.96s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   0% 264/60000 [09:29<70:41:26,  4.26s/it]
#
#  20% 4/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 265/60000 [09:30<50:58:22,  3.07s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 266/60000 [09:30<37:11:32,  2.24s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   0% 267/60000 [09:30<27:35:02,  1.66s/it]
#
#  35% 7/20 [00:02<00:03,  3.27it/s]
# Total progress:   0% 268/60000 [09:31<20:48:24,  1.25s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 269/60000 [09:31<16:03:37,  1.03it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   0% 270/60000 [09:31<12:48:20,  1.30it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   0% 271/60000 [09:32<10:28:17,  1.58it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   0% 272/60000 [09:32<8:50:13,  1.88it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 273/60000 [09:32<7:42:42,  2.15it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   0% 274/60000 [09:33<6:55:34,  2.40it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   0% 275/60000 [09:33<6:21:02,  2.61it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 276/60000 [09:33<5:56:54,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 277/60000 [09:33<5:41:42,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 278/60000 [09:34<5:29:27,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 279/60000 [09:34<5:21:23,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 280/60000 [09:34<5:16:20,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1397634:  25% 750/3000 [10:50<29:17,  1.28it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   0% 281/60000 [10:12<191:59:42, 11.57s/it]
#
#   5% 1/20 [00:00<00:05,  3.37it/s]
# Total progress:   0% 282/60000 [10:13<135:52:26,  8.19s/it]
#
#  10% 2/20 [00:00<00:05,  3.37it/s]
# Total progress:   0% 283/60000 [10:13<96:40:03,  5.83s/it]
#
#  15% 3/20 [00:00<00:05,  3.29it/s]
# Total progress:   0% 284/60000 [10:13<69:11:41,  4.17s/it]
#
#  20% 4/20 [00:01<00:04,  3.27it/s]
# Total progress:   0% 285/60000 [10:13<49:55:31,  3.01s/it]
#
#  25% 5/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 286/60000 [10:14<36:27:15,  2.20s/it]
#
#  30% 6/20 [00:01<00:04,  3.30it/s]
# Total progress:   0% 287/60000 [10:14<27:02:56,  1.63s/it]
#
#  35% 7/20 [00:02<00:03,  3.28it/s]
# Total progress:   0% 288/60000 [10:14<20:26:30,  1.23s/it]
#
#  40% 8/20 [00:02<00:03,  3.29it/s]
# Total progress:   0% 289/60000 [10:15<15:47:38,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.31it/s]
# Total progress:   0% 290/60000 [10:15<12:35:33,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.29it/s]
# Total progress:   0% 291/60000 [10:15<10:19:45,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 292/60000 [10:16<8:43:46,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.30it/s]
# Total progress:   0% 293/60000 [10:16<7:37:56,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.29it/s]
# Total progress:   0% 294/60000 [10:16<6:51:50,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   0% 295/60000 [10:16<6:18:32,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 296/60000 [10:17<5:55:45,  2.80it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   0% 297/60000 [10:17<5:40:35,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 298/60000 [10:17<5:29:38,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   0% 299/60000 [10:18<5:20:56,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   0% 300/60000 [10:18<5:15:43,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.29it/s]
# loss: 0.1392472:  27% 800/3000 [11:33<24:57,  1.47it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   1% 301/60000 [10:55<189:14:18, 11.41s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   1% 302/60000 [10:56<133:57:38,  8.08s/it]
#
#  10% 2/20 [00:00<00:05,  3.33it/s]
# Total progress:   1% 303/60000 [10:56<95:21:56,  5.75s/it]
#
#  15% 3/20 [00:00<00:05,  3.23it/s]
# Total progress:   1% 304/60000 [10:56<68:16:53,  4.12s/it]
#
#  20% 4/20 [00:01<00:04,  3.24it/s]
# Total progress:   1% 305/60000 [10:57<49:16:52,  2.97s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   1% 306/60000 [10:57<36:00:54,  2.17s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   1% 307/60000 [10:57<26:44:36,  1.61s/it]
#
#  35% 7/20 [00:02<00:03,  3.27it/s]
# Total progress:   1% 308/60000 [10:57<20:14:01,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   1% 309/60000 [10:58<15:39:07,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.29it/s]
# Total progress:   1% 310/60000 [10:58<12:30:17,  1.33it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   1% 311/60000 [10:58<10:15:47,  1.62it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   1% 312/60000 [10:59<8:40:49,  1.91it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   1% 313/60000 [10:59<7:36:35,  2.18it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   1% 314/60000 [10:59<6:51:09,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 315/60000 [11:00<6:18:05,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   1% 316/60000 [11:00<5:55:35,  2.80it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   1% 317/60000 [11:00<5:40:43,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   1% 318/60000 [11:00<5:29:44,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   1% 319/60000 [11:01<5:20:51,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.28it/s]
# Total progress:   1% 320/60000 [11:01<5:16:37,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1495857:  28% 850/3000 [12:16<24:49,  1.44it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   1% 321/60000 [11:38<189:16:18, 11.42s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   1% 322/60000 [11:39<133:59:51,  8.08s/it]
#
#  10% 2/20 [00:00<00:05,  3.32it/s]
# Total progress:   1% 323/60000 [11:39<95:23:21,  5.75s/it]
#
#  15% 3/20 [00:00<00:05,  3.23it/s]
# Total progress:   1% 324/60000 [11:39<68:17:04,  4.12s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   1% 325/60000 [11:40<49:16:55,  2.97s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   1% 326/60000 [11:40<36:00:39,  2.17s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   1% 327/60000 [11:40<26:46:14,  1.62s/it]
#
#  35% 7/20 [00:02<00:03,  3.25it/s]
# Total progress:   1% 328/60000 [11:41<20:14:41,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   1% 329/60000 [11:41<15:39:59,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   1% 330/60000 [11:41<12:30:31,  1.33it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   1% 331/60000 [11:41<10:16:39,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   1% 332/60000 [11:42<8:42:01,  1.91it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   1% 333/60000 [11:42<7:37:32,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   1% 334/60000 [11:42<6:51:13,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 335/60000 [11:43<6:18:51,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 336/60000 [11:43<5:56:38,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 337/60000 [11:43<5:42:20,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.25it/s]
# Total progress:   1% 338/60000 [11:44<5:30:41,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.26it/s]
# Total progress:   1% 339/60000 [11:44<5:22:32,  3.08it/s]
#
#  95% 19/20 [00:05<00:00,  3.26it/s]
# Total progress:   1% 340/60000 [11:44<5:17:18,  3.13it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1668734:  30% 900/3000 [13:00<26:24,  1.33it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   1% 341/60000 [12:23<194:32:59, 11.74s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   1% 342/60000 [12:23<137:41:04,  8.31s/it]
#
#  10% 2/20 [00:00<00:05,  3.33it/s]
# Total progress:   1% 343/60000 [12:23<97:55:58,  5.91s/it]
#
#  15% 3/20 [00:00<00:05,  3.27it/s]
# Total progress:   1% 344/60000 [12:24<70:05:46,  4.23s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   1% 345/60000 [12:24<50:33:31,  3.05s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   1% 346/60000 [12:24<36:53:36,  2.23s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   1% 347/60000 [12:24<27:22:22,  1.65s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   1% 348/60000 [12:25<20:40:04,  1.25s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   1% 349/60000 [12:25<15:58:25,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   1% 350/60000 [12:25<12:42:58,  1.30it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   1% 351/60000 [12:26<10:25:42,  1.59it/s]
#
#  55% 11/20 [00:03<00:02,  3.26it/s]
# Total progress:   1% 352/60000 [12:26<8:48:20,  1.88it/s]
#
#  60% 12/20 [00:03<00:02,  3.27it/s]
# Total progress:   1% 353/60000 [12:26<7:42:03,  2.15it/s]
#
#  65% 13/20 [00:03<00:02,  3.26it/s]
# Total progress:   1% 354/60000 [12:27<6:55:04,  2.40it/s]
#
#  70% 14/20 [00:04<00:01,  3.26it/s]
# Total progress:   1% 355/60000 [12:27<6:20:56,  2.61it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 356/60000 [12:27<5:58:15,  2.77it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   1% 357/60000 [12:28<5:42:22,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   1% 358/60000 [12:28<5:30:20,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   1% 359/60000 [12:28<5:22:32,  3.08it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   1% 360/60000 [12:28<5:16:36,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1526655:  32% 950/3000 [13:44<25:27,  1.34it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   1% 361/60000 [13:06<190:51:48, 11.52s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   1% 362/60000 [13:06<135:05:36,  8.15s/it]
#
#  10% 2/20 [00:00<00:05,  3.35it/s]
# Total progress:   1% 363/60000 [13:07<96:08:27,  5.80s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   1% 364/60000 [13:07<68:49:35,  4.15s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   1% 365/60000 [13:07<49:39:57,  3.00s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   1% 366/60000 [13:08<36:16:34,  2.19s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   1% 367/60000 [13:08<26:57:58,  1.63s/it]
#
#  35% 7/20 [00:02<00:04,  3.24it/s]
# Total progress:   1% 368/60000 [13:08<20:22:16,  1.23s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   1% 369/60000 [13:09<15:45:22,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   1% 370/60000 [13:09<12:34:58,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   1% 371/60000 [13:09<10:19:05,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   1% 372/60000 [13:09<8:42:38,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# ...
#
#  10% 2/20 [00:00<00:05,  3.35it/s]
# Total progress:   2% 1043/60000 [37:54<96:15:10,  5.88s/it]
#
#  15% 3/20 [00:00<00:05,  3.25it/s]
# Total progress:   2% 1044/60000 [37:55<68:51:55,  4.21s/it]
#
#  20% 4/20 [00:01<00:04,  3.27it/s]
# Total progress:   2% 1045/60000 [37:55<49:41:21,  3.03s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1046/60000 [37:55<36:17:16,  2.22s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1047/60000 [37:55<26:56:36,  1.65s/it]
#
#  35% 7/20 [00:02<00:04,  3.25it/s]
# Total progress:   2% 1048/60000 [37:56<20:20:27,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1049/60000 [37:56<15:43:15,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   2% 1050/60000 [37:56<12:32:26,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   2% 1051/60000 [37:57<10:15:25,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1052/60000 [37:57<8:39:49,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   2% 1053/60000 [37:57<7:34:54,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1054/60000 [37:58<6:48:32,  2.40it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1055/60000 [37:58<6:14:53,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1056/60000 [37:58<5:52:17,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1057/60000 [37:59<5:36:49,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1058/60000 [37:59<5:25:09,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1059/60000 [37:59<5:16:50,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1060/60000 [37:59<5:12:01,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1611497:  90% 2700/3000 [39:15<04:05,  1.22it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1061/60000 [38:38<191:02:40, 11.67s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   2% 1062/60000 [38:38<135:12:05,  8.26s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1063/60000 [38:38<96:12:29,  5.88s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   2% 1064/60000 [38:39<68:50:57,  4.21s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   2% 1065/60000 [38:39<49:40:26,  3.03s/it]
#
#  25% 5/20 [00:01<00:04,  3.27it/s]
# Total progress:   2% 1066/60000 [38:39<36:15:25,  2.21s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1067/60000 [38:39<26:56:02,  1.65s/it]
#
#  35% 7/20 [00:02<00:04,  3.24it/s]
# Total progress:   2% 1068/60000 [38:40<20:20:27,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.26it/s]
# Total progress:   2% 1069/60000 [38:40<15:42:48,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   2% 1070/60000 [38:40<12:31:35,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   2% 1071/60000 [38:41<10:15:15,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1072/60000 [38:41<8:40:11,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1073/60000 [38:41<7:34:24,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1074/60000 [38:42<6:47:21,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1075/60000 [38:42<6:14:07,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1076/60000 [38:42<5:52:05,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1077/60000 [38:42<5:36:02,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1078/60000 [38:43<5:24:28,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1079/60000 [38:43<5:17:10,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1080/60000 [38:43<5:13:00,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1520625:  92% 2750/3000 [39:59<02:58,  1.40it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1081/60000 [39:21<189:58:15, 11.61s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   2% 1082/60000 [39:22<134:26:53,  8.22s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1083/60000 [39:22<95:39:29,  5.85s/it]
#
#  15% 3/20 [00:00<00:05,  3.26it/s]
# Total progress:   2% 1084/60000 [39:22<68:28:08,  4.18s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   2% 1085/60000 [39:23<49:24:06,  3.02s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1086/60000 [39:23<36:03:59,  2.20s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   2% 1087/60000 [39:23<26:46:48,  1.64s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   2% 1088/60000 [39:23<20:14:20,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1089/60000 [39:24<15:39:10,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.28it/s]
# Total progress:   2% 1090/60000 [39:24<12:29:33,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.25it/s]
# Total progress:   2% 1091/60000 [39:24<10:13:35,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1092/60000 [39:25<8:38:55,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1093/60000 [39:25<7:33:27,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1094/60000 [39:25<6:47:47,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1095/60000 [39:26<6:15:22,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1096/60000 [39:26<5:52:36,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1097/60000 [39:26<5:37:04,  2.91it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   2% 1098/60000 [39:27<5:24:57,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1099/60000 [39:27<5:17:15,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1100/60000 [39:27<5:12:12,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1607872:  93% 2800/3000 [40:43<02:23,  1.39it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1101/60000 [40:06<192:50:33, 11.79s/it]
#
#   5% 1/20 [00:00<00:05,  3.35it/s]
# Total progress:   2% 1102/60000 [40:06<136:27:37,  8.34s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1103/60000 [40:06<97:04:09,  5.93s/it]
#
#  15% 3/20 [00:00<00:05,  3.26it/s]
# Total progress:   2% 1104/60000 [40:07<69:26:51,  4.24s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   2% 1105/60000 [40:07<50:04:56,  3.06s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   2% 1106/60000 [40:07<36:32:58,  2.23s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   2% 1107/60000 [40:08<27:05:43,  1.66s/it]
#
#  35% 7/20 [00:02<00:03,  3.28it/s]
# Total progress:   2% 1108/60000 [40:08<20:26:33,  1.25s/it]
#
#  40% 8/20 [00:02<00:03,  3.29it/s]
# Total progress:   2% 1109/60000 [40:08<15:47:32,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.30it/s]
# Total progress:   2% 1110/60000 [40:08<12:34:23,  1.30it/s]
#
#  50% 10/20 [00:03<00:03,  3.28it/s]
# Total progress:   2% 1111/60000 [40:09<10:16:59,  1.59it/s]
#
#  55% 11/20 [00:03<00:02,  3.29it/s]
# Total progress:   2% 1112/60000 [40:09<8:40:33,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.30it/s]
# Total progress:   2% 1113/60000 [40:09<7:34:28,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.29it/s]
# Total progress:   2% 1114/60000 [40:10<6:47:53,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1115/60000 [40:10<6:14:31,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1116/60000 [40:10<5:51:24,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1117/60000 [40:11<5:36:19,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1118/60000 [40:11<5:24:57,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1119/60000 [40:11<5:16:18,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1120/60000 [40:11<5:11:35,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.29it/s]
# loss: 0.1578250:  95% 2850/3000 [41:27<01:56,  1.29it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1121/60000 [40:50<190:48:09, 11.67s/it]
#
#   5% 1/20 [00:00<00:05,  3.36it/s]
# Total progress:   2% 1122/60000 [40:50<135:02:04,  8.26s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1123/60000 [40:50<96:05:51,  5.88s/it]
#
#  15% 3/20 [00:00<00:05,  3.23it/s]
# Total progress:   2% 1124/60000 [40:51<68:45:46,  4.20s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   2% 1125/60000 [40:51<49:36:51,  3.03s/it]
#
#  25% 5/20 [00:01<00:04,  3.27it/s]
# Total progress:   2% 1126/60000 [40:51<36:13:09,  2.21s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1127/60000 [40:51<26:53:08,  1.64s/it]
#
#  35% 7/20 [00:02<00:03,  3.25it/s]
# Total progress:   2% 1128/60000 [40:52<20:18:29,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1129/60000 [40:52<15:42:21,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1130/60000 [40:52<12:30:25,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   2% 1131/60000 [40:53<10:14:36,  1.60it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1132/60000 [40:53<8:38:51,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.29it/s]
# Total progress:   2% 1133/60000 [40:53<7:33:18,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1134/60000 [40:54<6:46:57,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1135/60000 [40:54<6:13:35,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1136/60000 [40:54<5:51:20,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.29it/s]
# Total progress:   2% 1137/60000 [40:54<5:35:20,  2.93it/s]
#
#  85% 17/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1138/60000 [40:55<5:24:09,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1139/60000 [40:55<5:16:40,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1140/60000 [40:55<5:11:05,  3.15it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1468944:  97% 2900/3000 [42:10<01:13,  1.37it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1141/60000 [41:33<185:35:22, 11.35s/it]
#
#   5% 1/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1142/60000 [41:33<131:22:52,  8.04s/it]
#
#  10% 2/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1143/60000 [41:33<93:31:51,  5.72s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   2% 1144/60000 [41:33<66:58:44,  4.10s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   2% 1145/60000 [41:34<48:21:56,  2.96s/it]
#
#  25% 5/20 [00:01<00:04,  3.27it/s]
# Total progress:   2% 1146/60000 [41:34<35:20:36,  2.16s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1147/60000 [41:34<26:16:18,  1.61s/it]
#
#  35% 7/20 [00:02<00:03,  3.25it/s]
# Total progress:   2% 1148/60000 [41:35<19:53:04,  1.22s/it]
#
#  40% 8/20 [00:02<00:03,  3.26it/s]
# Total progress:   2% 1149/60000 [41:35<15:24:57,  1.06it/s]
#
#  45% 9/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1150/60000 [41:35<12:17:49,  1.33it/s]
#
#  50% 10/20 [00:03<00:03,  3.26it/s]
# Total progress:   2% 1151/60000 [41:36<10:05:22,  1.62it/s]
#
#  55% 11/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1152/60000 [41:36<8:33:22,  1.91it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1153/60000 [41:36<7:30:09,  2.18it/s]
#
#  65% 13/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1154/60000 [41:36<6:45:33,  2.42it/s]
#
#  70% 14/20 [00:04<00:01,  3.26it/s]
# Total progress:   2% 1155/60000 [41:37<6:12:58,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1156/60000 [41:37<5:51:04,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1157/60000 [41:37<5:36:01,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   2% 1158/60000 [41:38<5:24:08,  3.03it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1159/60000 [41:38<5:16:06,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.29it/s]
# Total progress:   2% 1160/60000 [41:38<5:11:53,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1627633:  98% 2950/3000 [42:54<00:38,  1.29it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1161/60000 [42:16<187:45:56, 11.49s/it]
#
#   5% 1/20 [00:00<00:05,  3.34it/s]
# Total progress:   2% 1162/60000 [42:16<132:53:16,  8.13s/it]
#
#  10% 2/20 [00:00<00:05,  3.36it/s]
# Total progress:   2% 1163/60000 [42:16<94:35:31,  5.79s/it]
#
#  15% 3/20 [00:00<00:05,  3.24it/s]
# Total progress:   2% 1164/60000 [42:17<67:43:01,  4.14s/it]
#
#  20% 4/20 [00:01<00:04,  3.25it/s]
# Total progress:   2% 1165/60000 [42:17<48:52:14,  2.99s/it]
#
#  25% 5/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1166/60000 [42:17<35:42:03,  2.18s/it]
#
#  30% 6/20 [00:01<00:04,  3.28it/s]
# Total progress:   2% 1167/60000 [42:18<26:30:58,  1.62s/it]
#
#  35% 7/20 [00:02<00:03,  3.26it/s]
# Total progress:   2% 1168/60000 [42:18<20:03:24,  1.23s/it]
#
#  40% 8/20 [00:02<00:03,  3.26it/s]
# Total progress:   2% 1169/60000 [42:18<15:31:37,  1.05it/s]
#
#  45% 9/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1170/60000 [42:19<12:24:42,  1.32it/s]
#
#  50% 10/20 [00:03<00:03,  3.24it/s]
# Total progress:   2% 1171/60000 [42:19<10:09:42,  1.61it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1172/60000 [42:19<8:36:22,  1.90it/s]
#
#  60% 12/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1173/60000 [42:20<7:32:38,  2.17it/s]
#
#  65% 13/20 [00:03<00:02,  3.26it/s]
# Total progress:   2% 1174/60000 [42:20<6:46:33,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1175/60000 [42:20<6:13:06,  2.63it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1176/60000 [42:20<5:51:18,  2.79it/s]
#
#  80% 16/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1177/60000 [42:21<5:36:00,  2.92it/s]
#
#  85% 17/20 [00:05<00:00,  3.27it/s]
# Total progress:   2% 1178/60000 [42:21<5:24:13,  3.02it/s]
#
#  90% 18/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1179/60000 [42:21<5:16:37,  3.10it/s]
#
#  95% 19/20 [00:05<00:00,  3.28it/s]
# Total progress:   2% 1180/60000 [42:22<5:12:08,  3.14it/s]
#
# 100% 20/20 [00:06<00:00,  3.27it/s]
# loss: 0.1629831: 100% 3000/3000 [43:37<00:00,  1.33it/s]
#
#   0% 0/20 [00:00<?, ?it/s]
# Total progress:   2% 1181/60000 [43:00<190:59:39, 11.69s/it]
#
#   5% 1/20 [00:00<00:05,  3.37it/s]
# Total progress:   2% 1182/60000 [43:00<135:09:49,  8.27s/it]
#
#  10% 2/20 [00:00<00:05,  3.35it/s]
# Total progress:   2% 1183/60000 [43:01<96:09:43,  5.89s/it]
#
#  15% 3/20 [00:00<00:05,  3.26it/s]
# Total progress:   2% 1184/60000 [43:01<68:48:54,  4.21s/it]
#
#  20% 4/20 [00:01<00:04,  3.26it/s]
# Total progress:   2% 1185/60000 [43:01<49:38:16,  3.04s/it]
#
#  25% 5/20 [00:01<00:04,  3.29it/s]
# Total progress:   2% 1186/60000 [43:01<36:13:51,  2.22s/it]
#
#  30% 6/20 [00:01<00:04,  3.29it/s]
# Total progress:   2% 1187/60000 [43:02<26:52:53,  1.65s/it]
#
#  35% 7/20 [00:02<00:03,  3.27it/s]
# Total progress:   2% 1188/60000 [43:02<20:18:15,  1.24s/it]
#
#  40% 8/20 [00:02<00:03,  3.28it/s]
# Total progress:   2% 1189/60000 [43:02<15:41:34,  1.04it/s]
#
#  45% 9/20 [00:02<00:03,  3.29it/s]
# Total progress:   2% 1190/60000 [43:03<12:30:24,  1.31it/s]
#
#  50% 10/20 [00:03<00:03,  3.27it/s]
# Total progress:   2% 1191/60000 [43:03<10:14:52,  1.59it/s]
#
#  55% 11/20 [00:03<00:02,  3.27it/s]
# Total progress:   2% 1192/60000 [43:03<8:39:27,  1.89it/s]
#
#  60% 12/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1193/60000 [43:04<7:33:36,  2.16it/s]
#
#  65% 13/20 [00:03<00:02,  3.28it/s]
# Total progress:   2% 1194/60000 [43:04<6:47:10,  2.41it/s]
#
#  70% 14/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1195/60000 [43:04<6:14:32,  2.62it/s]
#
#  75% 15/20 [00:04<00:01,  3.28it/s]
# Total progress:   2% 1196/60000 [43:04<5:52:19,  2.78it/s]
#
#  80% 16/20 [00:04<00:01,  3.27it/s]
# Total progress:   2% 1197/60000 [43:05<5:37:46,  2.90it/s]
#
#  85% 17/20 [00:05<00:00,  3.26it/s]
# Total progress:   2% 1198/60000 [43:05<5:25:45,  3.01it/s]
#
#  90% 18/20 [00:05<00:00,  3.27it/s]
# Total progress:   2% 1199/60000 [43:05<5:17:24,  3.09it/s]
#
#  95% 19/20 [00:05<00:00,  3.27it/s]
# Total progress:   2% 1200/60000 [43:06<5:12:48,  3.13it/s]
#
# 100% 20/20 [00:06<00:00,  3.28it/s]
# loss: 0.1629831: : 3001it [43:45,  1.14it/s]
# Applying cross attention optimization (Doggettx).

# %%
# !COMMANDLINE_ARGS="--help"

# %% [markdown]
# 終了後に実行
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# %cd /content/AR/Ager dis out
# !find ./ -name '*.txt' -exec sed -i 's/cosplay_photo//g' {} \;
# Out:
# /content/AR/Ager dis out

# %%
#!zip -r /content/drive/MyDrive/AI/AgeR-out /content/drive/MyDrive/AI

# %%
# !zip -r /content/r /content/AR

# %%
shutil.move("/content/stable-diffusion-webui.zip","/content/drive/MyDrive/download")

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"

# %% [markdown]
# # 新しいセクション

# %%
shutil.copytree("/content/drive/MyDrive/AI/traning AI/train imagi/Ager dis out","/content/AR/Ager dis out")
# Out:
# '/content/AR/Ager dis out'

# %%
# %cd /content/AR/Ager dis out
# !find ./ -name '*.txt' -exec sed -i 's/ clothes_hanger,//g' {} \;
# Out:
# /content/AR/Ager dis out

# %%
shutil.rmtree("/content/AR/Ager dis out")

# %%
# %cd /content/AR/Ager dis out
import glob
file_names = glob.glob('.//*.txt')

for file_name in file_names:
    os.remove(file_name)
# Out:
# /content/AR/Ager dis out

# %%
/content/drive/MyDrive/download/AgeR out

# %%
import glob

# %%
# %cd /content/stable-diffusion-webui/AgeR

# %%
	
print(glob.glob('./jpg/*'))

# %%
import glob
import os
# %cd /content/AR/Ager dis out/
files = glob.glob("*.png")
for i, old_name in enumerate(files):
    # ファイル名の決定
    new_name = "AgeR{0:03d}.jpg".format(i + 1)
    # ファイル名の変更
    os.rename(old_name, new_name)
    # 変更の表示
    print(old_name + " → " + new_name)

# %%
# %cd /content/drive/MyDrive/AI/イメージデータベース/test
file_name = ".txt"

with open(file_name, encoding="cp932") as f:
    data_lines = f.read()

# 文字列置換
data_lines = data_lines.replace("test", "")

# 同じファイル名で保存
with open(file_name, mode="w", encoding="cp932") as f:
    f.write(data_lines)
# Out:
# /content/drive/MyDrive/AI/イメージデータベース/test
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-7a9b11deed8a> in <module>
#       2 file_name = "*.txt"
#       3
# ----> 4 with open(file_name, encoding="cp932") as f:
#       5     data_lines = f.read()
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '*.txt'

# %%
# !pip install pillow
